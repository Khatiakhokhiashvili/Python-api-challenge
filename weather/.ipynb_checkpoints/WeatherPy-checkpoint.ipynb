# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 596

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"
# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}q={city}&appid={weather_api_key}&units=metric"


    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))


   

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()



        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
       
        
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

    # pause to avoid rate limiting
    time.sleep(1)

# Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | stanley
# Processing Record 2 of Set 1 | punta arenas
# Processing Record 3 of Set 1 | booue
# Processing Record 4 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 5 of Set 1 | sandnessjoen
# Processing Record 6 of Set 1 | abu dhabi
# Processing Record 7 of Set 1 | college
# Processing Record 8 of Set 1 | tazovsky
# Processing Record 9 of Set 1 | naze
# Processing Record 10 of Set 1 | queenstown
# Processing Record 11 of Set 1 | grytviken
# Processing Record 12 of Set 1 | taoudenni
# Processing Record 13 of Set 1 | ilulissat
# Processing Record 14 of Set 1 | east london
# Processing Record 15 of Set 1 | aykhal
# Processing Record 16 of Set 1 | uliastay
# Processing Record 17 of Set 1 | cabo san lucas
# Processing Record 18 of Set 1 | vilyuchinsk
# Processing Record 19 of Set 1 | adamstown
# Processing Record 20 of Set 1 | tsengel
# Processing Record 21 of Set 1 | ta`u
# Processing Record 22 of Set 1 | bolobo
# Processing Record 23 of Set 1 | albany
# Processing Record 24 of Set 1 | dryden
# Processing Record 25 of Set 1 | sitka
# Processing Record 26 of Set 1 | udachny
# Processing Record 27 of Set 1 | edinburgh of the seven seas
# Processing Record 28 of Set 1 | trairi
# Processing Record 29 of Set 1 | aasiaat
# Processing Record 30 of Set 1 | bethel
# Processing Record 31 of Set 1 | remire-montjoly
# Processing Record 32 of Set 1 | vadso
# Processing Record 33 of Set 1 | akureyri
# Processing Record 34 of Set 1 | mertola
# Processing Record 35 of Set 1 | marka
# Processing Record 36 of Set 1 | nogliki
# Processing Record 37 of Set 1 | ulsteinvik
# Processing Record 38 of Set 1 | nemuro
# Processing Record 39 of Set 1 | leh
# Processing Record 40 of Set 1 | gaspe
# Processing Record 41 of Set 1 | colonia
# Processing Record 42 of Set 1 | papatowai
# Processing Record 43 of Set 1 | manokwari
# Processing Record 44 of Set 1 | yellowknife
# Processing Record 45 of Set 1 | cherdyn'
# Processing Record 46 of Set 1 | qamdo
# Processing Record 47 of Set 1 | itoman
# Processing Record 48 of Set 1 | port-aux-francais
# Processing Record 49 of Set 1 | iskateley
# Processing Record 50 of Set 1 | blackmans bay
# Processing Record 0 of Set 2 | waitangi
# Processing Record 1 of Set 2 | bredasdorp
# Processing Record 2 of Set 2 | ribeira grande
# Processing Record 3 of Set 2 | petropavlovsk-kamchatsky
# Processing Record 4 of Set 2 | kadugli
# Processing Record 5 of Set 2 | howard springs
# Processing Record 6 of Set 2 | arraial do cabo
# Processing Record 7 of Set 2 | fort bragg
# Processing Record 8 of Set 2 | puerto natales
# Processing Record 9 of Set 2 | alice springs
# Processing Record 10 of Set 2 | prince rupert
# Processing Record 11 of Set 2 | le vauclin
# Processing Record 12 of Set 2 | as sulayyil
# Processing Record 13 of Set 2 | ghadamis
# Processing Record 14 of Set 2 | talnakh
# Processing Record 15 of Set 2 | kerikeri
# Processing Record 16 of Set 2 | la passe
# Processing Record 17 of Set 2 | mirnyy
# Processing Record 18 of Set 2 | palmer
# Processing Record 19 of Set 2 | ushuaia
# Processing Record 20 of Set 2 | atar
# Processing Record 21 of Set 2 | khovd
# Processing Record 22 of Set 2 | ath thawrah
# Processing Record 23 of Set 2 | tiksi
# Processing Record 24 of Set 2 | bozhou
# Processing Record 25 of Set 2 | utrik
# Processing Record 26 of Set 2 | princeville
# Processing Record 27 of Set 2 | puerto ayora
# Processing Record 28 of Set 2 | west island
# Processing Record 29 of Set 2 | tura
# Processing Record 30 of Set 2 | kavaratti
# Processing Record 31 of Set 2 | coquimbo
# Processing Record 32 of Set 2 | invercargill
# Processing Record 33 of Set 2 | kashin
# Processing Record 34 of Set 2 | galle
# Processing Record 35 of Set 2 | kavak
# Processing Record 36 of Set 2 | ciudad bolivar
# Processing Record 37 of Set 2 | avarua
# Processing Record 38 of Set 2 | dahab
# Processing Record 39 of Set 2 | tinghir
# Processing Record 40 of Set 2 | antsiranana
# Processing Record 41 of Set 2 | irituia
# Processing Record 42 of Set 2 | zomba
# Processing Record 43 of Set 2 | kocakoy
# Processing Record 44 of Set 2 | merritt
# Processing Record 45 of Set 2 | iqaluit
# Processing Record 46 of Set 2 | san-pedro
# Processing Record 47 of Set 2 | peniche
# Processing Record 48 of Set 2 | noosa heads
# Processing Record 49 of Set 2 | nagqu
# Processing Record 0 of Set 3 | hamilton
# Processing Record 1 of Set 3 | rabigh
# Processing Record 2 of Set 3 | sarina
# Processing Record 3 of Set 3 | neryungri
# Processing Record 4 of Set 3 | goz beida
# Processing Record 5 of Set 3 | san jose de lourdes
# City not found. Skipping...
# Processing Record 6 of Set 3 | kodiak
# Processing Record 7 of Set 3 | puerto madero
# Processing Record 8 of Set 3 | chitapur
# Processing Record 9 of Set 3 | puerto san carlos
# City not found. Skipping...
# Processing Record 10 of Set 3 | hesperia
# Processing Record 11 of Set 3 | wailua homesteads
# Processing Record 12 of Set 3 | chonchi
# Processing Record 13 of Set 3 | kasongo-lunda
# Processing Record 14 of Set 3 | moussoro
# Processing Record 15 of Set 3 | qaqortoq
# Processing Record 16 of Set 3 | zhangatas
# Processing Record 17 of Set 3 | la puebla de cazalla
# Processing Record 18 of Set 3 | mirny
# Processing Record 19 of Set 3 | nar'yan-mar
# Processing Record 20 of Set 3 | brookings
# Processing Record 21 of Set 3 | khost
# Processing Record 22 of Set 3 | juneau
# Processing Record 23 of Set 3 | bilibino
# Processing Record 24 of Set 3 | tara
# Processing Record 25 of Set 3 | lebu
# Processing Record 26 of Set 3 | uturoa
# Processing Record 27 of Set 3 | susuman
# Processing Record 28 of Set 3 | barguzin
# Processing Record 29 of Set 3 | dunhua
# Processing Record 30 of Set 3 | port elizabeth
# Processing Record 31 of Set 3 | isiro
# Processing Record 32 of Set 3 | port mathurin
# Processing Record 33 of Set 3 | papao
# Processing Record 34 of Set 3 | port said
# Processing Record 35 of Set 3 | idri
# Processing Record 36 of Set 3 | margaret river
# Processing Record 37 of Set 3 | dunedin
# Processing Record 38 of Set 3 | ikungi
# Processing Record 39 of Set 3 | baganga
# Processing Record 40 of Set 3 | mineiros
# Processing Record 41 of Set 3 | carhuamayo
# Processing Record 42 of Set 3 | machhlishahr
# Processing Record 43 of Set 3 | eisleben lutherstadt
# City not found. Skipping...
# Processing Record 44 of Set 3 | egra
# Processing Record 45 of Set 3 | georgetown
# Processing Record 46 of Set 3 | kiwira
# Processing Record 47 of Set 3 | al qadarif
# Processing Record 48 of Set 3 | tibati
# Processing Record 49 of Set 3 | simanggang
# Processing Record 0 of Set 4 | guerrero negro
# Processing Record 1 of Set 4 | jamestown
# Processing Record 2 of Set 4 | san matias
# Processing Record 3 of Set 4 | jayapura
# Processing Record 4 of Set 4 | lerwick
# Processing Record 5 of Set 4 | pineville
# Processing Record 6 of Set 4 | garoowe
# Processing Record 7 of Set 4 | arvayheer
# Processing Record 8 of Set 4 | campbell river
# Processing Record 9 of Set 4 | constantia
# Processing Record 10 of Set 4 | ghat
# Processing Record 11 of Set 4 | walvis bay
# Processing Record 12 of Set 4 | nuuk
# Processing Record 13 of Set 4 | ingeniero jacobacci
# Processing Record 14 of Set 4 | manismata
# Processing Record 15 of Set 4 | terenos
# Processing Record 16 of Set 4 | isafjordur
# Processing Record 17 of Set 4 | arno
# Processing Record 18 of Set 4 | new norfolk
# Processing Record 19 of Set 4 | geraldton
# Processing Record 20 of Set 4 | san antonio de pale
# Processing Record 21 of Set 4 | pajan
# Processing Record 22 of Set 4 | melfort
# Processing Record 23 of Set 4 | afaahiti
# Processing Record 24 of Set 4 | bardai
# Processing Record 25 of Set 4 | tolanaro
# Processing Record 26 of Set 4 | kingston
# Processing Record 27 of Set 4 | sisimiut
# Processing Record 28 of Set 4 | bajil
# Processing Record 29 of Set 4 | flin flon
# Processing Record 30 of Set 4 | pandan
# Processing Record 31 of Set 4 | yuzhno-kurilsk
# Processing Record 32 of Set 4 | hawaiian paradise park
# Processing Record 33 of Set 4 | minas de marcona
# Processing Record 34 of Set 4 | saipan
# Processing Record 35 of Set 4 | puerto baquerizo moreno
# Processing Record 36 of Set 4 | mukhorshibir'
# City not found. Skipping...
# Processing Record 37 of Set 4 | yiyang
# Processing Record 38 of Set 4 | volksrust
# Processing Record 39 of Set 4 | hammerfest
# Processing Record 40 of Set 4 | el granada
# Processing Record 41 of Set 4 | lagrange
# Processing Record 42 of Set 4 | sierra grande
# Processing Record 43 of Set 4 | kouango
# Processing Record 44 of Set 4 | atafu village
# Processing Record 45 of Set 4 | hadibu
# Processing Record 46 of Set 4 | anadyr
# Processing Record 47 of Set 4 | sao joao da barra
# Processing Record 48 of Set 4 | pekan
# Processing Record 49 of Set 4 | klyuchi
# Processing Record 0 of Set 5 | carnarvon
# Processing Record 1 of Set 5 | at taj
# Processing Record 2 of Set 5 | midland
# Processing Record 3 of Set 5 | umba
# Processing Record 4 of Set 5 | qarauyl
# Processing Record 5 of Set 5 | coaticook
# Processing Record 6 of Set 5 | sao joao dos patos
# Processing Record 7 of Set 5 | muzayri'
# City not found. Skipping...
# Processing Record 8 of Set 5 | mount isa
# Processing Record 9 of Set 5 | whitehorse
# Processing Record 10 of Set 5 | lompoc
# Processing Record 11 of Set 5 | ciudad lazaro cardenas
# Processing Record 12 of Set 5 | obock
# Processing Record 13 of Set 5 | pimentel
# Processing Record 14 of Set 5 | kruisfontein
# Processing Record 15 of Set 5 | vredendal
# Processing Record 16 of Set 5 | leua
# Processing Record 17 of Set 5 | trevelin
# Processing Record 18 of Set 5 | fuglafjordur
# Processing Record 19 of Set 5 | itaituba
# Processing Record 20 of Set 5 | peterhead
# Processing Record 21 of Set 5 | el kala
# Processing Record 22 of Set 5 | millom
# Processing Record 23 of Set 5 | kidal
# Processing Record 24 of Set 5 | greenville
# Processing Record 25 of Set 5 | protaras
# Processing Record 26 of Set 5 | tres arroyos
# Processing Record 27 of Set 5 | kokoda
# Processing Record 28 of Set 5 | penn yan
# Processing Record 29 of Set 5 | uthal
# Processing Record 30 of Set 5 | enewetak
# Processing Record 31 of Set 5 | north bay
# Processing Record 32 of Set 5 | longyearbyen
# Processing Record 33 of Set 5 | daru
# Processing Record 34 of Set 5 | hami
# Processing Record 35 of Set 5 | makubetsu
# Processing Record 36 of Set 5 | port macquarie
# Processing Record 37 of Set 5 | kristiansand
# Processing Record 38 of Set 5 | butterworth
# Processing Record 39 of Set 5 | mchinji
# Processing Record 40 of Set 5 | port alfred
# Processing Record 41 of Set 5 | mahriz
# Processing Record 42 of Set 5 | saint-philippe
# Processing Record 43 of Set 5 | urumqi
# Processing Record 44 of Set 5 | bull savanna
# Processing Record 45 of Set 5 | toliara
# Processing Record 46 of Set 5 | waingapu
# Processing Record 47 of Set 5 | sile
# Processing Record 48 of Set 5 | lichtenfels
# Processing Record 49 of Set 5 | zhangye
# Processing Record 0 of Set 6 | rundu
# Processing Record 1 of Set 6 | fale old settlement
# Processing Record 2 of Set 6 | okha
# Processing Record 3 of Set 6 | constitucion
# Processing Record 4 of Set 6 | tshabong
# Processing Record 5 of Set 6 | atbara
# Processing Record 6 of Set 6 | oranjemund
# Processing Record 7 of Set 6 | kismayo
# Processing Record 8 of Set 6 | muang phonsavan
# Processing Record 9 of Set 6 | mikun'
# Processing Record 10 of Set 6 | san ignacio
# Processing Record 11 of Set 6 | thompson
# Processing Record 12 of Set 6 | puttalam
# Processing Record 13 of Set 6 | khorugh
# Processing Record 14 of Set 6 | laredo
# Processing Record 15 of Set 6 | zambezi
# Processing Record 16 of Set 6 | varzea da palma
# Processing Record 17 of Set 6 | belmonte
# Processing Record 18 of Set 6 | magadan
# Processing Record 19 of Set 6 | westport
# Processing Record 20 of Set 6 | east ballina
# Processing Record 21 of Set 6 | egilsstadir
# Processing Record 22 of Set 6 | olonkinbyen
# Processing Record 23 of Set 6 | south weber
# Processing Record 24 of Set 6 | boende
# Processing Record 25 of Set 6 | huarmey
# Processing Record 26 of Set 6 | hermanus
# Processing Record 27 of Set 6 | boksitogorsk
# Processing Record 28 of Set 6 | vikulovo
# Processing Record 29 of Set 6 | gaigeturi
# Processing Record 30 of Set 6 | huangnihe
# Processing Record 31 of Set 6 | umatac village
# City not found. Skipping...
# Processing Record 32 of Set 6 | 'ohonua
# City not found. Skipping...
# Processing Record 33 of Set 6 | ardanuc
# Processing Record 34 of Set 6 | yangor
# City not found. Skipping...
# Processing Record 35 of Set 6 | fortuna
# Processing Record 36 of Set 6 | qingyuan
# Processing Record 37 of Set 6 | olinda
# Processing Record 38 of Set 6 | tadine
# Processing Record 39 of Set 6 | dingli
# Processing Record 40 of Set 6 | port hedland
# Processing Record 41 of Set 6 | nema
# Processing Record 42 of Set 6 | dudinka
# Processing Record 43 of Set 6 | ain beni mathar
# City not found. Skipping...
# Processing Record 44 of Set 6 | tari
# Processing Record 45 of Set 6 | howrah
# Processing Record 46 of Set 6 | santa ana
# Processing Record 47 of Set 6 | hirara
# Processing Record 48 of Set 6 | vila velha
# Processing Record 49 of Set 6 | suez
# Processing Record 0 of Set 7 | plouzane
# Processing Record 1 of Set 7 | rikaze
# Processing Record 2 of Set 7 | savalou
# Processing Record 3 of Set 7 | bereznik
# Processing Record 4 of Set 7 | tabas
# Processing Record 5 of Set 7 | carlos chagas
# Processing Record 6 of Set 7 | palikir - national government center
# Processing Record 7 of Set 7 | grand falls-windsor
# Processing Record 8 of Set 7 | lihue
# Processing Record 9 of Set 7 | namibe
# Processing Record 10 of Set 7 | rio verde
# Processing Record 11 of Set 7 | bela vista
# Processing Record 12 of Set 7 | nungua
# Processing Record 13 of Set 7 | ketchikan
# Processing Record 14 of Set 7 | barberton
# Processing Record 15 of Set 7 | keflavik
# Processing Record 16 of Set 7 | demre
# Processing Record 17 of Set 7 | merizo village
# Processing Record 18 of Set 7 | carthage
# Processing Record 19 of Set 7 | revda
# Processing Record 20 of Set 7 | sibut
# Processing Record 21 of Set 7 | solnechnyy
# Processing Record 22 of Set 7 | sinabang
# Processing Record 23 of Set 7 | nuku'alofa
# Processing Record 24 of Set 7 | boysun
# Processing Record 25 of Set 7 | polyarnyy
# Processing Record 26 of Set 7 | santa maria del oro
# Processing Record 27 of Set 7 | taos
# Processing Record 28 of Set 7 | berezovo
# Processing Record 29 of Set 7 | ouesso
# Processing Record 30 of Set 7 | lincoln city
# Processing Record 31 of Set 7 | laguna
# Processing Record 32 of Set 7 | ancud
# Processing Record 33 of Set 7 | badiyah
# Processing Record 34 of Set 7 | topolobampo
# Processing Record 35 of Set 7 | port lincoln
# Processing Record 36 of Set 7 | vorkuta
# Processing Record 37 of Set 7 | great falls
# Processing Record 38 of Set 7 | pundong
# Processing Record 39 of Set 7 | kayangel
# Processing Record 40 of Set 7 | san patricio
# Processing Record 41 of Set 7 | kragero
# Processing Record 42 of Set 7 | yaren
# Processing Record 43 of Set 7 | hithadhoo
# Processing Record 44 of Set 7 | tofol
# Processing Record 45 of Set 7 | shakawe
# Processing Record 46 of Set 7 | vodnyy
# Processing Record 47 of Set 7 | otjimbingwe
# Processing Record 48 of Set 7 | piti village
# Processing Record 49 of Set 7 | paola
# Processing Record 0 of Set 8 | burang
# Processing Record 1 of Set 8 | talakan
# Processing Record 2 of Set 8 | nova vicosa
# Processing Record 3 of Set 8 | greenland
# Processing Record 4 of Set 8 | tselinnoye
# Processing Record 5 of Set 8 | sao vicente
# Processing Record 6 of Set 8 | sumbe
# Processing Record 7 of Set 8 | kapuskasing
# Processing Record 8 of Set 8 | gamba
# Processing Record 9 of Set 8 | cadale
# Processing Record 10 of Set 8 | axim
# Processing Record 11 of Set 8 | cambria
# Processing Record 12 of Set 8 | nyzhni sirohozy
# Processing Record 13 of Set 8 | mount gambier
# Processing Record 14 of Set 8 | borovskoy
# Processing Record 15 of Set 8 | tarrafal de sao nicolau
# Processing Record 16 of Set 8 | paramonga
# Processing Record 17 of Set 8 | manaure
# Processing Record 18 of Set 8 | salinopolis
# Processing Record 19 of Set 8 | badger
# Processing Record 20 of Set 8 | haiku-pauwela
# Processing Record 21 of Set 8 | ouellah
# City not found. Skipping...
# Processing Record 22 of Set 8 | thai binh
# Processing Record 23 of Set 8 | kon tum
# Processing Record 24 of Set 8 | trenggalek
# Processing Record 25 of Set 8 | wotho
# Processing Record 26 of Set 8 | vila franca do campo
# Processing Record 27 of Set 8 | ushtobe
# Processing Record 28 of Set 8 | katsuura
# Processing Record 29 of Set 8 | cafayate
# Processing Record 30 of Set 8 | moyale
# Processing Record 31 of Set 8 | siwa oasis
# Processing Record 32 of Set 8 | akhmet'a
# Processing Record 33 of Set 8 | newman
# Processing Record 34 of Set 8 | al kawa
# Processing Record 35 of Set 8 | chibougamau
# Processing Record 36 of Set 8 | touros
# Processing Record 37 of Set 8 | denbigh
# Processing Record 38 of Set 8 | tarawa
# Processing Record 39 of Set 8 | berdigestyakh
# Processing Record 40 of Set 8 | harstad
# Processing Record 41 of Set 8 | tazacorte
# Processing Record 42 of Set 8 | seydi
# Processing Record 43 of Set 8 | garachico
# Processing Record 44 of Set 8 | batie
# Processing Record 45 of Set 8 | gereida
# Processing Record 46 of Set 8 | hirtshals
# Processing Record 47 of Set 8 | krasnovishersk
# Processing Record 48 of Set 8 | acarau
# Processing Record 49 of Set 8 | malanje
# Processing Record 0 of Set 9 | madalena
# Processing Record 1 of Set 9 | eyl
# Processing Record 2 of Set 9 | igarka
# Processing Record 3 of Set 9 | ust-nera
# Processing Record 4 of Set 9 | paita
# Processing Record 5 of Set 9 | ca mau
# Processing Record 6 of Set 9 | mejit
# Processing Record 7 of Set 9 | broken hill
# Processing Record 8 of Set 9 | bikenibeu village
# Processing Record 9 of Set 9 | sapporo
# Processing Record 10 of Set 9 | novoleushkovskaya
# Processing Record 11 of Set 9 | birao
# Processing Record 12 of Set 9 | puerto aysen
# Processing Record 13 of Set 9 | crane
# Processing Record 14 of Set 9 | khrystynivka
# Processing Record 15 of Set 9 | mumford
# Processing Record 16 of Set 9 | harpanahalli
# Processing Record 17 of Set 9 | xiongzhou
# Processing Record 18 of Set 9 | tosno
# Processing Record 19 of Set 9 | conde
# Processing Record 20 of Set 9 | rukban
# City not found. Skipping...
# Processing Record 21 of Set 9 | tamarin
# Processing Record 22 of Set 9 | whyalla stuart
# City not found. Skipping...
# Processing Record 23 of Set 9 | sveti nikole
# Processing Record 24 of Set 9 | el charco
# Processing Record 25 of Set 9 | nabire
# Processing Record 26 of Set 9 | piacabucu
# Processing Record 27 of Set 9 | kultali
# City not found. Skipping...
# Processing Record 28 of Set 9 | sonsorol village
# City not found. Skipping...
# Processing Record 29 of Set 9 | tsiombe
# Processing Record 30 of Set 9 | liwonde
# Processing Record 31 of Set 9 | damavand
# Processing Record 32 of Set 9 | cooper's town
# Processing Record 33 of Set 9 | novaya igirma
# Processing Record 34 of Set 9 | ubari
# Processing Record 35 of Set 9 | biloela
# Processing Record 36 of Set 9 | ust'-ilimsk
# Processing Record 37 of Set 9 | peresvet
# Processing Record 38 of Set 9 | whakatane
# Processing Record 39 of Set 9 | jinchang
# Processing Record 40 of Set 9 | hasaki
# Processing Record 41 of Set 9 | south hedland
# Processing Record 42 of Set 9 | mata-utu
# Processing Record 43 of Set 9 | juan griego
# Processing Record 44 of Set 9 | mandalgovi
# Processing Record 45 of Set 9 | ulladulla
# Processing Record 46 of Set 9 | st. john's
# Processing Record 47 of Set 9 | north bondi
# Processing Record 48 of Set 9 | bamboo flat
# Processing Record 49 of Set 9 | malango
# Processing Record 0 of Set 10 | acapulco de juarez
# Processing Record 1 of Set 10 | flying fish cove
# Processing Record 2 of Set 10 | tome
# Processing Record 3 of Set 10 | lodwar
# Processing Record 4 of Set 10 | tannum sands
# Processing Record 5 of Set 10 | hounde
# Processing Record 6 of Set 10 | mendoza
# Processing Record 7 of Set 10 | fort st. john
# Processing Record 8 of Set 10 | kargopol'
# Processing Record 9 of Set 10 | sabang
# Processing Record 10 of Set 10 | kropachevo
# Processing Record 11 of Set 10 | kapa'a
# Processing Record 12 of Set 10 | vorgashor
# Processing Record 13 of Set 10 | luanda
# Processing Record 14 of Set 10 | nyurba
# Processing Record 15 of Set 10 | bonthe
# Processing Record 16 of Set 10 | mawlaik
# Processing Record 17 of Set 10 | castillos
# Processing Record 18 of Set 10 | marmande
# Processing Record 19 of Set 10 | motygino
# Processing Record 20 of Set 10 | gerze
# Processing Record 21 of Set 10 | hengchun
# Processing Record 22 of Set 10 | gueltat zemmour
# City not found. Skipping...
# Processing Record 23 of Set 10 | lensk
# Processing Record 24 of Set 10 | boambee east
# City not found. Skipping...
# Processing Record 25 of Set 10 | katsina-ala
# Processing Record 26 of Set 10 | cide
# Processing Record 27 of Set 10 | tralee
# Processing Record 28 of Set 10 | kone
# Processing Record 29 of Set 10 | callao
# Processing Record 30 of Set 10 | lewistown
# Processing Record 31 of Set 10 | aykol
# City not found. Skipping...
# Processing Record 32 of Set 10 | veraval
# Processing Record 33 of Set 10 | qujing
# Processing Record 34 of Set 10 | anloga
# Processing Record 35 of Set 10 | kununurra
# Processing Record 36 of Set 10 | smithers
# Processing Record 37 of Set 10 | garwolin
# Processing Record 38 of Set 10 | plaquemine
# Processing Record 39 of Set 10 | port antonio
# Processing Record 40 of Set 10 | turkmenbasy
# Processing Record 41 of Set 10 | talbahat
# Processing Record 42 of Set 10 | takeo
# Processing Record 43 of Set 10 | ytyk-kyuyel'
# City not found. Skipping...
# Processing Record 44 of Set 10 | conceicao do araguaia
# Processing Record 45 of Set 10 | nkove
# Processing Record 46 of Set 10 | fuvahmulah
# City not found. Skipping...
# Processing Record 47 of Set 10 | kaoma
# Processing Record 48 of Set 10 | mount pearl
# Processing Record 49 of Set 10 | curuca
# Processing Record 0 of Set 11 | happy valley-goose bay
# Processing Record 1 of Set 11 | saudarkrokur
# Processing Record 2 of Set 11 | rabo de peixe
# Processing Record 3 of Set 11 | labytnangi
# Processing Record 4 of Set 11 | georgievka
# Processing Record 5 of Set 11 | mil'kovo
# Processing Record 6 of Set 11 | tangalle
# Processing Record 7 of Set 11 | chinchilla
# Processing Record 8 of Set 11 | al ghayzah
# Processing Record 9 of Set 11 | necochea
# Processing Record 10 of Set 11 | porto torres
# Processing Record 11 of Set 11 | kargasok
# Processing Record 12 of Set 11 | fort dodge
# Processing Record 13 of Set 11 | port augusta
# Processing Record 14 of Set 11 | mokhsogollokh
# Processing Record 15 of Set 11 | mantsala
# Processing Record 16 of Set 11 | macapa
# Processing Record 17 of Set 11 | eraan
# Processing Record 18 of Set 11 | cannonvale
# Processing Record 19 of Set 11 | folkston
# Processing Record 20 of Set 11 | opuwo
# Processing Record 21 of Set 11 | pariang
# City not found. Skipping...
# Processing Record 22 of Set 11 | costa teguise
# City not found. Skipping...
# Processing Record 23 of Set 11 | tarinkot
# Processing Record 24 of Set 11 | lembar
# City not found. Skipping...
# Processing Record 25 of Set 11 | baruun-urt
# Processing Record 26 of Set 11 | toga village
# City not found. Skipping...
# Processing Record 27 of Set 11 | przemysl
# Processing Record 28 of Set 11 | saldanha
# Processing Record 29 of Set 11 | alcacer do sal
# Processing Record 30 of Set 11 | dumas
# Processing Record 31 of Set 11 | yeppoon city centre
# City not found. Skipping...
# Processing Record 32 of Set 11 | vanino
# Processing Record 33 of Set 11 | usinsk
# Processing Record 34 of Set 11 | recreo
# Processing Record 35 of Set 11 | kailua-kona
# Processing Record 36 of Set 11 | san clemente del tuyu
# Processing Record 37 of Set 11 | mana
# Processing Record 38 of Set 11 | motueka
# Processing Record 39 of Set 11 | ulan bator
# Processing Record 40 of Set 11 | al hamul
# Processing Record 41 of Set 11 | iawar
# Processing Record 42 of Set 11 | severnoye
# Processing Record 43 of Set 11 | luganville
# Processing Record 44 of Set 11 | ondjiva
# Processing Record 45 of Set 11 | nyaunglebin
# Processing Record 46 of Set 11 | richards bay
# Processing Record 47 of Set 11 | pekanbaru
# Processing Record 48 of Set 11 | beloyarskiy
# Processing Record 49 of Set 11 | maitum
# Processing Record 0 of Set 12 | pemangkat
# Processing Record 1 of Set 12 | valdivia
# Processing Record 2 of Set 12 | gazojak
# Processing Record 3 of Set 12 | severo-yeniseyskiy
# Processing Record 4 of Set 12 | pithampur
# Processing Record 5 of Set 12 | laojunmiao
# Processing Record 6 of Set 12 | north syracuse
# Processing Record 7 of Set 12 | little river
# Processing Record 8 of Set 12 | kirensk
# Processing Record 9 of Set 12 | boyolangu
# Processing Record 10 of Set 12 | cold springs
# Processing Record 11 of Set 12 | los palacios
# Processing Record 12 of Set 12 | takoradi
# Processing Record 13 of Set 12 | olyokminsk
# Processing Record 14 of Set 12 | ringkobing
# Processing Record 15 of Set 12 | nizhniy odes
# Processing Record 16 of Set 12 | rongelap
# Processing Record 17 of Set 12 | zhengjiatun
# Processing Record 18 of Set 12 | emmett
# Processing Record 19 of Set 12 | leo
# Processing Record 20 of Set 12 | sampit
# Processing Record 21 of Set 12 | weno
# Processing Record 22 of Set 12 | jutai
# Processing Record 23 of Set 12 | hayden
# Processing Record 24 of Set 12 | dompu
# Processing Record 25 of Set 12 | dolores
# Processing Record 26 of Set 12 | road town
# Processing Record 27 of Set 12 | palmas de monte alto
# Processing Record 28 of Set 12 | anibare
# City not found. Skipping...
# Processing Record 29 of Set 12 | mariental
# Processing Record 30 of Set 12 | chimore
# Processing Record 31 of Set 12 | portland
# Processing Record 32 of Set 12 | ranot
# Processing Record 33 of Set 12 | itu
# Processing Record 34 of Set 12 | inyonga
# Processing Record 35 of Set 12 | posto fiscal rolim de moura
# Processing Record 36 of Set 12 | bodaybo
# Processing Record 37 of Set 12 | phu kradueng
# Processing Record 38 of Set 12 | puntarenas
# Processing Record 39 of Set 12 | vikhorevka
# Processing Record 40 of Set 12 | al ain city
# Processing Record 41 of Set 12 | vershino-darasunskiy
# Processing Record 42 of Set 12 | miajadas
# Processing Record 43 of Set 12 | gannan
# Processing Record 44 of Set 12 | savave village
# City not found. Skipping...
# Processing Record 45 of Set 12 | pisco
# Processing Record 46 of Set 12 | konarka
# Processing Record 47 of Set 12 | ati
# Processing Record 48 of Set 12 | slavske
# Processing Record 49 of Set 12 | camacupa
# Processing Record 0 of Set 13 | vung tau
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          574
# Lat           574
# Lng           574
# Max Temp      574
# Humidity      574
# Cloudiness    574
# Wind Speed    574
# Country       574
# Date          574
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#            City      Lat      Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0       stanley  54.8680  -1.6985      9.04        96         100        1.03
# 1  punta arenas -53.1500 -70.9167     -0.94        80         100        3.60
# 2         booue  -0.0921  11.9385     22.50        95          77        1.36
# 3  sandnessjoen  66.0217  12.6316     10.29        88         100        5.41
# 4     abu dhabi  24.4667  54.3667     33.86        73          20        0.51
#
#   Country        Date
# 0      GB  1719974339
# 1      CL  1719974340
# 2      GA  1719974341
# 3      NO  1719974343
# 4      AE  1719974344

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                  City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0             stanley  54.8680  -1.6985      9.04        96         100
# 1        punta arenas -53.1500 -70.9167     -0.94        80         100
# 2               booue  -0.0921  11.9385     22.50        95          77
# 3        sandnessjoen  66.0217  12.6316     10.29        88         100
# 4           abu dhabi  24.4667  54.3667     33.86        73          20
#
#          Wind Speed Country        Date
# City_ID
# 0              1.03      GB  1719974339
# 1              3.60      CL  1719974340
# 2              1.36      GA  1719974341
# 3              5.41      NO  1719974343
# 4              0.51      AE  1719974344

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], edgecolors="black")

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature (°C)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (°C)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity

city_data_df['Date'] = pd.to_datetime(city_data_df['Date'], unit='s')

# Get a representative date, for example, the date of the first record
representative_date = city_data_df['Date'].iloc[0].strftime('%Y-%m-%d')

# Build the scatter plot for latitude vs. humidity
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], edgecolors="black")

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Humidity ({representative_date})")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], edgecolors="black")

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Cloudiness ({representative_date})")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], edgecolors="black")

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Wind Speed ({representative_date})")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def plot_linear_regression(x_values, y_values, x_label, y_label, title, filename):
    # Perform linear regression
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[city_data_df["Lat"] >= 0]


# Display sample data
northern_hemi_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0             stanley  54.8680   -1.6985      9.04        96         100
# 3        sandnessjoen  66.0217   12.6316     10.29        88         100
# 4           abu dhabi  24.4667   54.3667     33.86        73          20
# 5             college  64.8569 -147.8028     23.97        48          75
# 6            tazovsky  67.4667   78.7000     13.68        50           2
#
#          Wind Speed Country                Date
# City_ID
# 0              1.03      GB 2024-07-03 02:38:59
# 3              5.41      NO 2024-07-03 02:39:03
# 4              0.51      AE 2024-07-03 02:39:04
# 5              5.14      US 2024-07-03 02:39:05
# 6              5.59      RU 2024-07-03 02:39:06

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df["Lat"] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                  City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1        punta arenas -53.1500 -70.9167     -0.94        80         100
# 2               booue  -0.0921  11.9385     22.50        95          77
# 8          queenstown -31.8976  26.8753      8.40        74           9
# 9           grytviken -54.2811 -36.5092     -4.50        76          17
# 12        east london -33.0153  27.9116     15.84        80          38
#
#          Wind Speed Country                Date
# City_ID
# 1              3.60      CL 2024-07-03 02:39:00
# 2              1.36      GA 2024-07-03 02:39:01
# 8              1.66      ZA 2024-07-03 02:35:09
# 9              0.41      GS 2024-07-03 02:39:10
# 12             1.94      ZA 2024-07-03 02:35:07

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
# Import linregress from scipy.stats
from scipy.stats import linregress

# Define a function to create Linear Regression plots
def plot_linear_regression(x_values, y_values, x_label, y_label, title, filename):
    # Perform linear regression
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    
    # Get regression values
    regress_values = x_values * slope + intercept
    
    # Create scatter plot
    plt.scatter(x_values, y_values)
    
    # Plot regression line
    plt.plot(x_values, regress_values, "r-")
    
    # Annotate the line equation
    plt.annotate(f"y = {slope:.2f}x + {intercept:.2f}", (min(x_values), min(y_values)), fontsize=15, color="red")
    
    # Set labels and title
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.title(title)
    
 
    
    # Show plot
    plt.show()

# Define variables for Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]

# Plot Latitude vs. Temperature
plot_linear_regression(x_values, y_values, "Latitude", "Max Temperature (°C)", "Linear Regression on Northern Hemisphere\nLatitude vs. Max Temperature", "Northern_Lat_vs_Temp.png")

# %%
# Linear regression on Southern Hemisphere

# Define a function to create Linear Regression plots
def plot_linear_regression(x_values, y_values, x_label, y_label, title, filename):
    # Perform linear regression
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    
    # Get regression values
    regress_values = x_values * slope + intercept
    
    # Create scatter plot
    plt.scatter(x_values, y_values)
    
    # Plot regression line
    plt.plot(x_values, regress_values, "r-")
    
    # Annotate the line equation
    plt.annotate(f"y = {slope:.2f}x + {intercept:.2f}", (min(x_values), min(y_values)), fontsize=15, color="red")
    
    # Set labels and title
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.title(title)
    
   
    # Show plot
    plt.show()

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE

# %%
# Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE

# %%
# Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE

# %%
# Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
